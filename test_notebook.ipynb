# %%
pip install jupyterlab matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/106.6 kB ? eta -:--:--
#      ------- ----------------------------- 20.5/106.6 kB 330.3 kB/s eta 0:00:01
#      ----------------- ------------------- 51.2/106.6 kB 525.1 kB/s eta 0:00:01
#      --------------------- --------------- 61.4/106.6 kB 544.7 kB/s eta 0:00:01
#      ---------------------------------- - 102.4/106.6 kB 737.3 kB/s eta 0:00:01
#      ---------------------------------- - 102.4/106.6 kB 737.3 kB/s eta 0:00:01
#      ---------------------------------- - 102.4/106.6 kB 737.3 kB/s eta 0:00:01
#      ---------------------------------- - 102.4/106.6 kB 737.3 kB/s eta 0:00:01
#      ---------------------------------- - 102.4/106.6 kB 737.3 kB/s eta 0:00:01
#      ---------------------------------- - 102.4/106.6 kB 737.3 kB/s eta 0:00:01
#      ---------------------------------- - 102.4/106.6 kB 737.3 kB/s eta 0:00:01
#      ---------------------------------- - 102.4/106.6 kB 737.3 kB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[i**2 for i in x]
plt.plot(x,y,marker='o')
plt.title("Test plot: x vs x^2")
plt.xlabel("x")
plt.ylabel("x^2")
plt.grid(True)
plt.show()
